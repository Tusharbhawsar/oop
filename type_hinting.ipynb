# %%
def add_num(a : int,b = int) ->int:
    return a + b

a = "str"
b = "ing"

add_num(a,b)
# Out:
# 'string'

# %%
import typing  as th

def input_Data(a:th.List,b:th.Dict[str,int]):

    return a,b


a = [2]
b= {"tushar":123}
input_Data(a,b)
# Out:
# ([2], {'tushar': 123})
